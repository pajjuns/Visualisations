# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = "C:\\Users\\PAJJU\\Desktop\\PAJJU$\\Promilo\\Data set for BA.xlsx"

# %%
df_1 = pd.read_excel(df, sheet_name = 0)
df_2 = pd.read_excel(df, sheet_name = 1)
df_3 = pd.read_excel(df, sheet_name = 2)
df_4 = pd.read_excel(df, sheet_name = 3)
df_5 = pd.read_excel(df, sheet_name = 4)
df_6 = pd.read_excel(df, sheet_name = 5)
df_7 = pd.read_excel(df, sheet_name = 6)
df_8 = pd.read_excel(df, sheet_name = 7)
df_9 = pd.read_excel(df, sheet_name = 8)
df_10 = pd.read_excel(df, sheet_name = 9)
df_11 = pd.read_excel(df, sheet_name = 10)
df_12 = pd.read_excel(df, sheet_name = 11)
df_13 = pd.read_excel(df, sheet_name = 12)
df_14 = pd.read_excel(df, sheet_name = 13)
df_15 = pd.read_excel(df, sheet_name = 14)

# %% [markdown]
# # **1. USER ACQUISITION**

# %%
df_2.head()
# Out:
#   First user default channel group  New users  Engaged sessions  \
# 0                          Display       9957             12008
# 1                   Organic Search       7652             18141
# 2                      Paid Search       3025              4408
# 3                           Direct       1903              4975
# 4                       Unassigned        325              1619
#
#    Engagement rate  Engaged sessions per user  Average engagement time  \
# 0         0.544457                   1.206107                 58.86209
# 1         0.813680                   2.367041                534.31280
# 2         0.474284                   1.458154                102.23780
# 3         0.318808                   2.261364               1128.88100
# 4         0.813159                   4.981538                798.34150
#
#    Event count  Conversions  Total revenue
# 0       204820        37434              0
# 1       770710       109801              0
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   First user default channel group  6 non-null      object
#  1   New users                         6 non-null      int64
#  2   Engaged sessions                  6 non-null      int64
#  3   Engagement rate                   6 non-null      float64
#  4   Engaged sessions per user         6 non-null      float64
#  5   Average engagement time           6 non-null      float64
#  6   Event count                       6 non-null      int64
#  7   Conversions                       6 non-null      int64
#  8   Total revenue                     6 non-null      int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 560.0+ bytes

# %%
df_2.shape
# Out:
# (6, 9)

# %%
df_2.isnull().sum()
# Out:
# First user default channel group    0
# New users                           0
# Engaged sessions                    0
# Engagement rate                     0
# Engaged sessions per user           0
# Average engagement time             0
# Event count                         0
# Conversions                         0
# Total revenue                       0
# dtype: int64

# %%
df_2.dtypes
# Out:
# First user default channel group     object
# New users                             int64
# Engaged sessions                      int64
# Engagement rate                     float64
# Engaged sessions per user           float64
# Average engagement time             float64
# Event count                           int64
# Conversions                           int64
# Total revenue                         int64
# dtype: object

# %%
df_2.describe()
# Out:
#          New users  Engaged sessions  Engagement rate  \
# count     6.000000          6.000000         6.000000
# mean   3812.000000       6860.666667         0.614435
# std    4083.739659       6894.604867         0.201367
# min      10.000000         13.000000         0.318808
# 25%     719.500000       2316.250000         0.491827
# 50%    2464.000000       4691.500000         0.633339
# 75%    6495.250000      10249.750000         0.790425
# max    9957.000000      18141.000000         0.813680
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                   6.000000                 6.000000       6.000000
# mean                    2.262367               461.322532  219754.833333
# std                     1.420806               437.111008  284869.104021
# min                     1.206107                58.862090     248.000000
# 25%                     1.339538               113.003350   45489.250000
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR USER ACQUISITION**

# %%
channel_group = df_2["First user default channel group"].value_counts()
new_users = df_2['New users']
plt.figure(figsize = (25,10))
plt.pie(new_users.values, labels=channel_group.index, autopct="%1.1f%%")
plt.title("Pie Chart of New Users by Channel group")
plt.legend(loc = 'upper right')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.bar(df_2['First user default channel group'], df_2['Engaged sessions'], color='green')
plt.xlabel('Channel Mode')
plt.ylabel('Engaged sessions')
plt.title('Engaged sessions based on Default Channel Group')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.bar(df_2['First user default channel group'], df_2['Engagement rate'], color='green')

plt.xlabel('Channel Mode')
plt.ylabel('Engagement Rate')
plt.title('Engagement Rate by Default channel group')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_2['First user default channel group'],df_2['Engaged sessions per user'],'s-g')
plt.xlabel('Channel Mode')
plt.ylabel('Engaged Sessions per user')
plt.title('Engaged Sessions per user based on Default Channel Group')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_2['First user default channel group'],df_2['Average engagement time'],'o-g')
plt.xlabel('Channel Mode')
plt.ylabel('Average Engagement Time')
plt.title('Average Engagement Time based on Default Channel Group')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.barh(df_2['First user default channel group'], df_2['Event count'], color='green')

plt.xlabel('Channel Mode')
plt.ylabel('Event Count')
plt.title('Event Count by Default channel group')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.bar(df_2['First user default channel group'], df_2['Conversions'], color='green')
plt.plot(df_2['First user default channel group'],df_2['Conversions'], marker = 'o', linestyle = '-.', color = '#00FF00')

plt.xlabel('Channel Mode')
plt.ylabel('Conversions')
plt.title('Conversion based on Default channel group')
plt.show()

# %% [markdown]
# # **2. TRAFFIC ACQUISITION**

# %%
df_3.head()
# Out:
#   Session default channel group  Users  Sessions  Engaged sessions  \
# 0                    Unassigned  20263     13448              1481
# 1                       Display   9613     18292             10613
# 2                Organic Search   7689     21241             17814
# 3                        Direct   4042     13220              7649
# 4                   Paid Search   2909      6788              3452
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                             34.11704                   0.073089
# 1                             28.52198                   1.104026
# 2                            195.94340                   2.316816
# 3                            177.17060                   1.892380
# 4                             36.65321                   1.186662
#
#    Events per session  Engagement rate  Event count  Conversions  \
# 0           18.023130         0.110128       242375       114161
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Session default channel group        6 non-null      object
#  1   Users                                6 non-null      int64
#  2   Sessions                             6 non-null      int64
#  3   Engaged sessions                     6 non-null      int64
#  4   Average engagement time per session  6 non-null      float64
#  5   Engaged sessions per user            6 non-null      float64
#  6   Events per session                   6 non-null      float64
#  7   Engagement rate                      6 non-null      float64
#  8   Event count                          6 non-null      int64
#  9   Conversions                          6 non-null      int64
#  10  Total revenue                        6 non-null      int64
# ...

# %%
df_3.shape
# Out:
# (6, 11)

# %%
df_3.isnull().sum()
# Out:
# Session default channel group          0
# Users                                  0
# Sessions                               0
# Engaged sessions                       0
# Average engagement time per session    0
# Engaged sessions per user              0
# Events per session                     0
# Engagement rate                        0
# Event count                            0
# Conversions                            0
# Total revenue                          0
# dtype: int64

# %%
df_3.describe()
# Out:
#               Users      Sessions  Engaged sessions  \
# count      6.000000      6.000000          6.000000
# mean    7421.166667  12167.500000       6836.833333
# std     7162.088199   7735.416104       6665.397735
# min       11.000000     16.000000         12.000000
# 25%     3192.250000   8396.000000       1973.750000
# 50%     5865.500000  13334.000000       5550.500000
# 75%     9132.000000  17081.000000       9872.000000
# max    20263.000000  21241.000000      17814.000000
#
#        Average engagement time per session  Engaged sessions per user  \
# count                             6.000000                   6.000000
# mean                             88.744788                   1.277314
# std                              76.756564                   0.772272
# min                              28.521980                   0.073089
# 25%                              34.751083                   1.094188
# 50%                              48.357855                   1.145344
# ...

# %%
df_3.head()
# Out:
#   Session default channel group  Users  Sessions  Engaged sessions  \
# 0                    Unassigned  20263     13448              1481
# 1                       Display   9613     18292             10613
# 2                Organic Search   7689     21241             17814
# 3                        Direct   4042     13220              7649
# 4                   Paid Search   2909      6788              3452
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                             34.11704                   0.073089
# 1                             28.52198                   1.104026
# 2                            195.94340                   2.316816
# 3                            177.17060                   1.892380
# 4                             36.65321                   1.186662
#
#    Events per session  Engagement rate  Event count  Conversions  \
# 0           18.023130         0.110128       242375       114161
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR TRAFFIC ACQUISITION**

# %%
channel_group2 = df_3["Session default channel group"].value_counts()
users = df_3['Users']
plt.figure(figsize = (25,10))
plt.pie(users.values, labels=channel_group2.index, autopct="%1.1f%%")
plt.title("Pie Chart of Users by Channel group")
plt.legend(loc = 'upper right')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.bar(df_3['Session default channel group'], df_3['Sessions'], color='teal')

plt.xlabel('Channel Mode')
plt.ylabel('Sessions')
plt.title('Sessions by Default channel group')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.barh(df_3['Session default channel group'], df_3['Engaged sessions'], color='teal')

plt.xlabel('Channel Mode')
plt.ylabel('Engaged Sessions')
plt.title('Engaged Sessions by Default channel group')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_3['Session default channel group'],df_3['Average engagement time per session'],marker = 'o', linestyle = '--', color = 'teal')
plt.xlabel('Channel Mode')
plt.ylabel('Engagement Time')
plt.title('Engagement Time based on Default Channel Group')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_3['Session default channel group'],df_3['Engaged sessions per user'],marker = 's', linestyle = '-', color = 'teal')
plt.fill_between(df_3['Session default channel group'],df_3['Engaged sessions per user'], color='teal', alpha=0.2)
plt.xlabel('Channel Mode')
plt.ylabel('Engagement Session per user')
plt.title('Engagement session per user based on Default Channel Group')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.barh(df_3['Session default channel group'], df_3['Events per session'], color='teal')

plt.xlabel('Channel Mode')
plt.ylabel('Events per session')
plt.title('Events per session by Default channel group')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_3['Session default channel group'],df_3['Engagement rate'], color = 'teal')
plt.xlabel('Channel Mode')
plt.ylabel('Engagement Rate')
plt.title('Engagement Rate based on Default Channel Group')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.bar(df_3['Session default channel group'], df_3['Event count'], color='teal')

plt.xlabel('Channel Mode')
plt.ylabel('Event count')
plt.title('Event count by Default channel group')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.bar(df_3['Session default channel group'], df_3['Conversions'], color='teal')
plt.plot(df_3['Session default channel group'], df_3['Conversions'],marker = 'o', linestyle = '-.', color = 'blue')
plt.xlabel('Channel Mode')
plt.ylabel('Conversions')
plt.title('Conversions by Default channel group')
plt.show()

# %% [markdown]
# # **3. CONVERSION REPORT**

# %%
df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Event name     18 non-null     object
#  1   Conversions    18 non-null     int64
#  2   Total users    18 non-null     int64
#  3   Total revenue  18 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 704.0+ bytes

# %%
df_5.shape
# Out:
# (18, 4)

# %%
df_5.isnull().sum()
# Out:
# Event name       0
# Conversions      0
# Total users      0
# Total revenue    0
# dtype: int64

# %%
df_5.describe()
# Out:
#         Conversions   Total users  Total revenue
# count     18.000000     18.000000           18.0
# mean   10773.000000   3468.777778            0.0
# std    25160.036433   7461.269980            0.0
# min       20.000000     10.000000            0.0
# 25%      127.250000     33.750000            0.0
# 50%      620.500000    246.500000            0.0
# 75%     1702.000000    940.500000            0.0
# max    94890.000000  23059.000000            0.0

# %%
df_5.head()
# Out:
#               Event name  Conversions  Total users  Total revenue
# 0   notification_receive        94890         1311              0
# 1          session_start        56203        21674              0
# 2             first_open        22872        23059              0
# 3             app_remove        12468        12538              0
# 4  Promilo111_otp_screen         1738          855              0

# %% [markdown]
# # **DATA ANALYSIS FOR CONVERSION REPORT**

# %%
df_sorted = df_5.sort_values(by='Conversions', ascending=False)
top = df_sorted.head(5)

plt.figure(figsize=(20, 8))
plt.bar(top['Event name'], top['Conversions'], color='purple')
plt.plot(top['Event name'], top['Conversions'],marker = 'o', linestyle = '--', color = '#301934')
plt.xlabel('Event name')
plt.ylabel('Conversions')
plt.title('Conversions by Events')
plt.show()

# %%
df_sorted = df_5.sort_values(by='Conversions', ascending=False)
bottom = df_sorted.tail(5)

plt.figure(figsize=(20, 8))
plt.bar(bottom['Event name'], bottom['Conversions'], color='purple')
plt.plot(bottom['Event name'], bottom['Conversions'],marker = 'o', linestyle = '--', color = '#301934')
plt.xlabel('Event name')
plt.ylabel('Conversions')
plt.title('Conversions by Least Events')
plt.show()

# %%
df_sorted2 = df_5.sort_values(by='Total users', ascending=False)
top2 = df_sorted2.head(5)

plt.figure(figsize=(20, 8))
plt.barh(top2['Event name'], top2['Total users'], color='purple')

plt.xlabel('Event name')
plt.ylabel('Total Users')
plt.title('Total Users by Event name')
plt.show()

# %%
df_sorted2 = df_5.sort_values(by='Total users', ascending=False)
bottom2 = df_sorted2.tail(5)

plt.figure(figsize=(20, 8))
plt.barh(bottom2['Event name'], bottom2['Total users'], color='purple')

plt.xlabel('Event name')
plt.ylabel('Total Users')
plt.title('Total Users by Event name')
plt.show()

# %% [markdown]
# # **4. EVENT REPORT**

# %%
df_4.head()
# Out:
#              Event name  Event count  Total users  Event count per user  \
# 0           screen_view       694729        23254             30.865870
# 1  notification_receive       125146         1700            138.896800
# 2       user_engagement       124836        22699              5.622230
# 3  notification_dismiss        70128         1369            144.000000
# 4         session_start        61163        23226              3.121357
#
#    Total revenue
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Event name            378 non-null    object
#  1   Event count           379 non-null    int64
#  2   Total users           379 non-null    int64
#  3   Event count per user  379 non-null    float64
#  4   Total revenue         379 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 14.9+ KB

# %%
df_4.shape
# Out:
# (379, 5)

# %%
df_4.isnull().sum()
# Out:
# Event name              1
# Event count             0
# Total users             0
# Event count per user    0
# Total revenue           0
# dtype: int64

# %%
df_4 = df_4.dropna()

# %%
df_4.isnull().sum()
# Out:
# Event name              0
# Event count             0
# Total users             0
# Event count per user    0
# Total revenue           0
# dtype: int64

# %%
df_4['Event count'] = df_4['Event count'].iloc[:-1]
df_4 = df_4.dropna()

# %%
df_4.describe()
# Out:
#          Event count   Total users  Event count per user  Total revenue
# count     377.000000    377.000000            377.000000          377.0
# mean     3497.212202    527.596817              3.195293            0.0
# std     37171.253720   2564.940184             10.408714            0.0
# min         1.000000      1.000000              0.000000            0.0
# 25%         7.000000      3.000000              1.254902            0.0
# 50%        63.000000     31.000000              1.750000            0.0
# 75%       514.000000    238.000000              2.756757            0.0
# max    694729.000000  23254.000000            144.000000            0.0

# %% [markdown]
# # **DATA ANALYSIS FOR EVENT REPORT**

# %%
df_4.head(15)
# Out:
#                        Event name  Event count  Total users  \
# 0                     screen_view     694729.0        23254
# 1            notification_receive     125146.0         1700
# 2                 user_engagement     124836.0        22699
# 3            notification_dismiss      70128.0         1369
# 4                   session_start      61163.0        23226
# 5                      first_open      22872.0        23059
# 6                      app_remove      18080.0        18030
# 7                Promilo113_login      12719.0         6174
# 8               Promilo1116_feeds       7942.0         1837
# 9                Promilo111_login       7449.0         3517
# 10               Promilo111_feeds       6240.0         1045
# 11  Promilo1116_my_rewards_screen       5863.0          884
# 12               Promilo106_feeds       5629.0         1146
# 13               Promilo113_feeds       5495.0         1376
# 14              Promilo1116_login       5315.0         2263
#
# ...

# %%
df4_ec = df_4.sort_values(by='Event count', ascending=False)
top4_ec = df4_ec.head(5)

plt.figure(figsize = (20,8))
plt.bar(top4_ec['Event name'], top4_ec['Event count'], color='grey')
plt.xlabel('Event name')
plt.ylabel('Event Count')
plt.title('Event Count based on top Event Names')
plt.show()

# %%
df4_ec = df_4.sort_values(by='Event count', ascending=False)
bottom4_ec = df4_ec.tail(5)

plt.figure(figsize = (20,8))
plt.bar(bottom4_ec['Event name'], bottom4_ec['Event count'], color='grey')
plt.xlabel('Event name')
plt.ylabel('Event Count')
plt.title('Event Count based on bottom Event Names')
plt.show()

# %%
df_sorted4 = df_4.sort_values(by='Total users', ascending=False)
top4 = df_sorted4.head(5)

plt.figure(figsize=(20, 8))
plt.barh(top4['Event name'], top4['Total users'], color='grey')

plt.xlabel('Event name')
plt.ylabel('Total Users')
plt.title('Total Users by Event name')
plt.show()

# %%
df4_aet = df_4.sort_values(by = 'Event count per user', ascending = False)
top4_aet = df4_aet.head(5)

plt.figure(figsize = (20,8))
plt.plot(top4_aet['Event name'],top4_aet['Event count per user'],marker = 'o', linestyle = '-.', color = 'black')
plt.fill_between(top4_aet['Event name'],top4_aet['Event count per user'], color='grey', alpha=0.2)
plt.xlabel('Event name')
plt.ylabel('Event count per user')
plt.title('Event count per user based on Event name')
plt.show()

# %% [markdown]
# # **5. PAGES AND SCREEN REPORT**

# %%
df_6.head()
# Out:
#   Page path and screen class   Views  Users  Views per user  \
# 0                    Flutter  156708   8726       17.958740
# 1               MainActivity   44326   8978        4.937180
# 2                      feeds   18514   4358        4.248279
# 3                      login   16883   7291        2.315595
# 4          my_rewards_screen   15381   2045        7.521271
#
#    Average engagement time  Event count  Conversions  Total revenue
# 0                 83.41222       203901          328              0
# 1                 78.29216        53374          101              0
# 2                 61.60005        37628          253              0
# 3                 34.88177        40772          435              0
# 4                 94.17995        32910            5              0

# %%
df_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Page path and screen class  42 non-null     object
#  1   Views                       42 non-null     int64
#  2   Users                       42 non-null     int64
#  3   Views per user              42 non-null     float64
#  4   Average engagement time     42 non-null     float64
#  5   Event count                 42 non-null     int64
#  6   Conversions                 42 non-null     int64
#  7   Total revenue               42 non-null     int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.8+ KB

# %%
df_6.describe()
# Out:
#                Views        Users  Views per user  Average engagement time  \
# count      42.000000    42.000000       42.000000                42.000000
# mean     7081.261905  1524.761905        3.036123                48.898515
# std     24926.556037  2628.069168        3.001363                58.750556
# min         0.000000     2.000000        0.000000                 0.001093
# 25%        69.250000    23.250000        1.510656                 9.340753
# 50%       736.500000   301.000000        1.864079                35.592545
# 75%      2734.750000  1402.500000        3.696037                67.387118
# max    156708.000000  9145.000000       17.958740               304.333300
#
#          Event count   Conversions  Total revenue
# count      42.000000     42.000000           42.0
# mean    13417.547619   2145.690476            0.0
# std     36182.217422  13652.911458            0.0
# min         4.000000      0.000000            0.0
# ...

# %%
df_6.shape
# Out:
# (42, 8)

# %%
df_6.isnull().sum()
# Out:
# Page path and screen class    0
# Views                         0
# Users                         0
# Views per user                0
# Average engagement time       0
# Event count                   0
# Conversions                   0
# Total revenue                 0
# dtype: int64

# %%
df_6['Page path and screen class'] = df_6['Page path and screen class'].iloc[:-1]
df_6 = df_6.dropna()

# %% [markdown]
# # **DATA ANALYSIS FOR PAGE AND SCREEN REPORT**

# %%
df6_views = df_6.sort_values(by='Views', ascending=False)
top6_views = df6_views.head(5)

plt.figure(figsize = (20,8))
plt.bar(top6_views['Page path and screen class'], top6_views['Views'], color='#000000')
plt.xlabel('Page path and screen class')
plt.ylabel('Views')
plt.title('Views across Pages and Screens')
plt.show()

# %%
df6_views = df_6.sort_values(by='Views', ascending=False)
bottom6_views = df6_views.tail(5)

plt.figure(figsize = (20,8))
plt.bar(bottom6_views['Page path and screen class'], bottom6_views['Views'], color='#000000')
plt.xlabel('Page path and screen class')
plt.ylabel('Views')
plt.title('Views across Least visited Pages and Screens')
plt.show()

# %%
df6_users = df_6.sort_values(by='Users', ascending=False)
top6_users = df6_users.head(5)

plt.figure(figsize = (20,8))
plt.bar(top6_users['Page path and screen class'], top6_users['Users'], color='#000000')
plt.xlabel('Page path and Screen Class')
plt.ylabel('Users')
plt.title('Users across Pages and Screens')
plt.show()

# %%
df6_users = df_6.sort_values(by='Users', ascending=False)
bottom6_users = df6_users.tail(7)

plt.figure(figsize = (20,8))
plt.bar(bottom6_users['Page path and screen class'], bottom6_users['Users'], color='#000000')
plt.xlabel('Page path and Screen Class')
plt.ylabel('Users')
plt.title('Users across least reached Pages and Screens')
plt.show()

# %%
df6_vpu = df_6.sort_values(by = 'Views per user', ascending = False)
top6_vpu = df6_vpu.head(7)

plt.figure(figsize = (20,8))
plt.plot(top6_vpu['Page path and screen class'],top6_vpu['Views per user'],marker = 'o', linestyle = '-', color = '#000000')
plt.xlabel('Page path and screen class')
plt.ylabel('Views per user')
plt.title('Views per user based on Page and screen class')
plt.show()

# %%
df6_aet = df_6.sort_values(by = 'Average engagement time', ascending = False)
top6_aet = df6_aet.head(5)

plt.figure(figsize = (20,8))
plt.plot(top6_aet['Page path and screen class'],top6_aet['Average engagement time'],marker = 'o', linestyle = '-.', color = '#000000')
plt.fill_between(top6_aet['Page path and screen class'],top6_aet['Average engagement time'], color='#000000', alpha=0.2)
plt.xlabel('Page path and screen class')
plt.ylabel('Average engagement time')
plt.title('Average engagement time based on Page and screen class')
plt.show()

# %%
df_6.head()
# Out:
#   Page path and screen class   Views  Users  Views per user  \
# 0                    Flutter  156708   8726       17.958740
# 1               MainActivity   44326   8978        4.937180
# 2                      feeds   18514   4358        4.248279
# 3                      login   16883   7291        2.315595
# 4          my_rewards_screen   15381   2045        7.521271
#
#    Average engagement time  Event count  Conversions  Total revenue
# 0                 83.41222       203901          328              0
# 1                 78.29216        53374          101              0
# 2                 61.60005        37628          253              0
# 3                 34.88177        40772          435              0
# 4                 94.17995        32910            5              0

# %%
df6_ecount = df_6.sort_values(by = 'Event count',ascending = False)
top6_ecount = df6_ecount.head(10)

plt.figure(figsize = (20,8))
plt.barh(top6_ecount['Page path and screen class'], top6_ecount['Event count'], color='#000000')
plt.xlabel('Page path and Screen Class')
plt.ylabel('Event Count')
plt.title('Event Count across Page and Screen class')
plt.show()

# %%
df6_conversions = df_6.sort_values(by='Conversions', ascending=False)
top6_conversions = df6_conversions.head(5)

plt.figure(figsize=(20, 8))
plt.bar(top6_conversions['Page path and screen class'], top6_conversions['Conversions'], color='#808080')
plt.plot(top6_conversions['Page path and screen class'], top6_conversions['Conversions'], marker ='o', linestyle = '-.', color = '#000000')
plt.xlabel('Page path and screen class')
plt.ylabel('Conversions')
plt.title('Conversions by Page and Screen class')
plt.show()

# %% [markdown]
# # **6. DEMOGRAPHICS REPORT**

# %%
df_9.head()
# Out:
#           Country  Users  New users  Engaged sessions  Engagement rate  \
# 0           India  23024      22528             41479         0.593626
# 1   United States    272        213               197         0.491272
# 2          Canada     37         18                25         0.416667
# 3       (not set)     36         36                17         0.459459
# 4  United Kingdom     20          8                13         0.371429
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.801555                334.81660      1312097
# 1                   0.724265                 50.96324         3157
# 2                   0.675676                 43.21622          410
# 3                   0.472222                 24.80556          241
# 4                   0.650000                 61.85000          289
#
#    Conversions  Total revenue
# 0       192766              0
# 1          643              0
# 2          121              0
# ...

# %%
df_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    47 non-null     object
#  1   Users                      47 non-null     int64
#  2   New users                  47 non-null     int64
#  3   Engaged sessions           47 non-null     int64
#  4   Engagement rate            47 non-null     float64
#  5   Engaged sessions per user  47 non-null     float64
#  6   Average engagement time    47 non-null     float64
#  7   Event count                47 non-null     int64
#  8   Conversions                47 non-null     int64
#  9   Total revenue              47 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 3.8+ KB

# %%
df_9.isnull().sum()
# Out:
# Country                      0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df_9.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count     47.000000     47.000000         47.000000        47.000000
# mean     500.148936    486.638298        890.340426         0.561662
# std     3357.099816   3285.103773       6049.238031         0.358970
# min        0.000000      0.000000          0.000000         0.000000
# 25%        1.000000      0.000000          1.000000         0.364286
# 50%        2.000000      1.000000          1.000000         0.533333
# 75%        7.000000      3.000000          6.000000         1.000000
# max    23024.000000  22528.000000      41479.000000         1.000000
#
#        Engaged sessions per user  Average engagement time   Event count  \
# count                  47.000000                47.000000  4.700000e+01
# mean                    0.835367                48.376626  2.805381e+04
# std                     0.568228                93.511799  1.913692e+05
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR DEMOGRAPHIC REPORT**

# %%
df9_users = df_9.sort_values(by='Users', ascending=False)
top9_users = df9_users.head(10)

plt.figure(figsize = (20,8))
plt.bar(top9_users['Country'], top9_users['Users'], color='#00008B')
plt.xlabel('Country')
plt.ylabel('Top Users')
plt.title('Top Users across Countries')
plt.show()

# %%
df9_nusers = df_9.sort_values(by='New users', ascending=False)
top9_nusers = df9_nusers.head(10)

plt.figure(figsize = (20,8))
plt.bar(top9_nusers['Country'], top9_nusers['New users'], color='#00008B')
plt.xlabel('Country')
plt.ylabel('New Users')
plt.title('New Users across Countries')
plt.show()

# %%
df9_es = df_9.sort_values(by='Engaged sessions', ascending=False)
top9_es = df9_es.head(10)

plt.figure(figsize = (20,8))
plt.barh(top9_es['Country'], top9_es['Engaged sessions'], color='#00008B')
plt.xlabel('Country')
plt.ylabel('Engaged Sessions')
plt.title('Engaged session based on Countries')
plt.show()

# %%
df9_erate = df_9.sort_values(by = 'Engagement rate', ascending = False)
top9_erate = df9_erate.head(10)

plt.figure(figsize = (20,8))
plt.plot(top9_erate['Country'],top9_erate['Engagement rate'],marker = 'o', linestyle = '-.', color = '#00008B')
plt.xlabel('Country')
plt.ylabel('Engagement rate')
plt.title('Engagement rate based on Top Countries')
plt.show()

# %%
df9_espu = df_9.sort_values(by = 'Engaged sessions per user', ascending = False)
top9_espu = df9_espu.head(10)

plt.figure(figsize = (20,8))
plt.plot(top9_espu['Country'],top9_espu['Engaged sessions per user'], marker = 's', linestyle = '--', color = '#00008B')
plt.fill_between(top9_espu['Country'],top9_espu['Engaged sessions per user'], color='#00008B', alpha=0.2)
plt.xlabel('Country')
plt.ylabel('Engagement Session per user')
plt.title('Engagement session per user based on Top 10 Countries')
plt.show()

# %%
df9_aet = df_9.sort_values(by = 'Average engagement time', ascending = False)
top9_aet = df9_aet.head(10)

plt.figure(figsize = (20,8))
plt.plot(top9_aet['Country'],top9_aet['Average engagement time'],marker = 'o',color = '#00008B')
plt.xlabel('Country')
plt.ylabel('Average Engagement time')
plt.title('Average engagement time based on Country')
plt.show()

# %%
df9_ecount = df_9.sort_values(by = 'Event count',ascending = False)
top9_ecount = df9_ecount.head(10)

plt.figure(figsize = (20,8))
plt.bar(top9_ecount['Country'], top9_ecount['Event count'], color='#00008B')
plt.xlabel('Country')
plt.ylabel('Event Count')
plt.title('Event Count across Countries')
plt.show()

# %%
df9_conversions = df_9.sort_values(by='Conversions', ascending=False)
top9_conversions = df9_conversions.head(10)

plt.figure(figsize=(20, 8))
plt.bar(top9_conversions['Country'], top9_conversions['Conversions'], color='#00008B')
plt.plot(top9_conversions['Country'], top9_conversions['Conversions'], marker ='o', linestyle = '-.', color = '#00008B')
plt.xlabel('Country')
plt.ylabel('Conversions')
plt.title('Conversions by Top Countries')
plt.show()

# %% [markdown]
# # **7. CITIWISE REPORTS**

# %%
df_10.head()
# Out:
#    Town/City  Users  New users  Engaged sessions  Engagement rate  \
# 0  Bengaluru   6097       5685             15013         0.769385
# 1      Patna   1594       1467              2127         0.440646
# 2  Hyderabad   1038        920              1578         0.569264
# 3     Indore    983        915              1241         0.426460
# 4    Lucknow    897        839              1125         0.450180
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   2.462359                762.20550       607200
# 1                   1.334379                 98.22208        38830
# 2                   1.520231                243.69080        96826
# 3                   1.262462                 67.89115        21383
# 4                   1.254181                 83.40580        21041
#
#    Conversions  Total revenue
# 0        62939              0
# 1         6980              0
# 2        34103              0
# 3         4121              0
# ...

# %%
df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Town/City                  574 non-null    object
#  1   Users                      574 non-null    int64
#  2   New users                  574 non-null    int64
#  3   Engaged sessions           574 non-null    int64
#  4   Engagement rate            574 non-null    float64
#  5   Engaged sessions per user  574 non-null    float64
#  6   Average engagement time    574 non-null    float64
#  7   Event count                574 non-null    int64
#  8   Conversions                574 non-null    int64
#  9   Total revenue              574 non-null    int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 45.0+ KB

# %%
df_10.isnull().sum()
# Out:
# Town/City                    0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df_10.describe()
# Out:
#              Users    New users  Engaged sessions  Engagement rate  \
# count   574.000000   574.000000         574.00000       574.000000
# mean     46.203833    39.846690          71.61324         0.489662
# std     290.091708   267.115856         656.03377         0.341660
# min       0.000000     0.000000           0.00000         0.000000
# 25%       1.000000     1.000000           1.00000         0.250000
# 50%       2.000000     1.000000           2.00000         0.497547
# 75%       7.750000     5.000000           7.00000         0.724026
# max    6097.000000  5685.000000       15013.00000         1.000000
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                 574.000000               574.000000     574.000000
# mean                    0.884915                94.093768    2297.088850
# std                     0.750856               202.850678   26179.153773
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR CITIWISE REPORT**

# %%
df_10.head()
# Out:
#    Town/City  Users  New users  Engaged sessions  Engagement rate  \
# 0  Bengaluru   6097       5685             15013         0.769385
# 1      Patna   1594       1467              2127         0.440646
# 2  Hyderabad   1038        920              1578         0.569264
# 3     Indore    983        915              1241         0.426460
# 4    Lucknow    897        839              1125         0.450180
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   2.462359                762.20550       607200
# 1                   1.334379                 98.22208        38830
# 2                   1.520231                243.69080        96826
# 3                   1.262462                 67.89115        21383
# 4                   1.254181                 83.40580        21041
#
#    Conversions  Total revenue
# 0        62939              0
# 1         6980              0
# 2        34103              0
# 3         4121              0
# ...

# %%
df_10_sorted = df_10.sort_values(by='Users', ascending=False)
top10 = df_10_sorted.head(5)

plt.figure(figsize = (20,8))
plt.bar(top10['Town/City'], top10['Users'], color='lime')
plt.xlabel('Town/City')
plt.ylabel('Top Users')
plt.title('Top Users across Cities')
plt.show()

# %%
df10_nusers = df_10.sort_values(by = 'New users',ascending = False)
top10_nusers = df10_nusers.head(5)

plt.figure(figsize = (20,8))
plt.bar(top10_nusers['Town/City'], top10_nusers['New users'], color='lime')
plt.xlabel('Town/City')
plt.ylabel('New Users')
plt.title('New Users across Cities')
plt.show()

# %%
df10_esessions = df_10.sort_values(by = 'Engaged sessions', ascending = False)
top10_esessions = df10_esessions.head(10)
plt.figure(figsize = (20,8))
plt.barh(top10_esessions['Town/City'], top10_esessions['Engaged sessions'], color = 'lime')
plt.xlabel('Town/City')
plt.ylabel('Engaged Sessions')
plt.title('Engaged Sessions by Top 10 Cities')
plt.show()

# %%
df10_erate = df_10.sort_values(by = 'Engagement rate', ascending = False)
top10_erate = df10_erate.head(10)

plt.figure(figsize = (20,8))
plt.plot(top10_erate['Town/City'],top10_erate['Engagement rate'],marker = 'o', linestyle = '-.', color = 'lime')
plt.xlabel('Town/City')
plt.ylabel('Engagement rate')
plt.title('Engagement rate based on Top Cities')
plt.show()

# %%
df10_espu = df_10.sort_values(by = 'Engaged sessions per user', ascending = False)
top_espu = df10_espu.head(10)

plt.figure(figsize = (20,8))
plt.plot(top_espu['Town/City'],top_espu['Engaged sessions per user'], marker = 's', linestyle = '--', color = 'lime')
plt.fill_between(top_espu['Town/City'],top_espu['Engaged sessions per user'], color='lime', alpha=0.2)
plt.xlabel('Town/City')
plt.ylabel('Engagement Session per user')
plt.title('Engagement session per user based on Top 10 Cities')
plt.show()

# %%
df10_aet = df_10.sort_values(by = 'Average engagement time', ascending = False)
top10_aet = df10_aet.head(5)

plt.figure(figsize = (20,8))
plt.plot(top10_aet['Town/City'],top10_aet['Average engagement time'],marker = 'o',color = 'lime')
plt.xlabel('Town/City')
plt.ylabel('Average Engagement time')
plt.title('Average engagement time based on Town/City')
plt.show()

# %%
df10_ecount = df_10.sort_values(by = 'Event count',ascending = False)
top10_ecount = df10_ecount.head(10)

plt.figure(figsize = (20,8))
plt.bar(top10_ecount['Town/City'], top10_ecount['Event count'], color='lime')
plt.xlabel('Town/City')
plt.ylabel('Event Count')
plt.title('Event Count across Cities')
plt.show()

# %%
df10_conversions = df_10.sort_values(by='Conversions', ascending=False)
top10_conversions = df10_conversions.head(5)

plt.figure(figsize=(20, 8))
plt.bar(top10_conversions['Town/City'], top10_conversions['Conversions'], color='lime')
plt.plot(top10_conversions['Town/City'], top10_conversions['Conversions'],'o--g')
plt.xlabel('Town/City')
plt.ylabel('Conversions')
plt.title('Conversions by Top Cities')
plt.show()

# %% [markdown]
# # **8. GENDER REPORT**

# %%
df_11.head()
# Out:
#     Gender  Users  New users  Engaged sessions  Engagement rate  \
# 0  unknown  13142      12691             23161         0.564077
# 1     male   7218       5877             10467         0.543091
# 2   female   4944       4304              7877         0.637710
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.762365                 439.5776       761771
# 1                   1.450125                 128.2319       282504
# 2                   1.593244                 208.7407       274254
#
#    Conversions  Total revenue
# 0        93180              0
# 1        65651              0
# 2        35083              0

# %%
df_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Gender                     3 non-null      object
#  1   Users                      3 non-null      int64
#  2   New users                  3 non-null      int64
#  3   Engaged sessions           3 non-null      int64
#  4   Engagement rate            3 non-null      float64
#  5   Engaged sessions per user  3 non-null      float64
#  6   Average engagement time    3 non-null      float64
#  7   Event count                3 non-null      int64
#  8   Conversions                3 non-null      int64
#  9   Total revenue              3 non-null      int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 368.0+ bytes

# %%
df_11.isnull().sum()
# Out:
# Gender                       0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df_11.shape
# Out:
# (3, 10)

# %%
df_11.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count      3.000000      3.000000          3.000000         3.000000
# mean    8434.666667   7624.000000      13835.000000         0.581626
# std     4232.258184   4458.076828       8179.714665         0.049691
# min     4944.000000   4304.000000       7877.000000         0.543091
# 25%     6081.000000   5090.500000       9172.000000         0.553584
# 50%     7218.000000   5877.000000      10467.000000         0.564077
# 75%    10180.000000   9284.000000      16814.000000         0.600893
# max    13142.000000  12691.000000      23161.000000         0.637710
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                   3.000000                 3.000000       3.000000
# mean                    1.601911               258.850067  439509.666667
# std                     0.156300               161.608316  279116.984160
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR GENDER REPORT**

# %%
gender_group = df_11["Gender"].value_counts()
users = df_11['Users']
plt.figure(figsize = (25,10))
plt.pie(users.values, labels=gender_group.index, autopct="%1.1f%%")
plt.title("Pie Chart of Users by Gender")
plt.legend(loc = 'upper right')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.bar(df_11['Gender'], df_11['New users'], color='plum')
plt.xlabel('Gender')
plt.ylabel('New Users')
plt.title('New Users across Genders')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.barh(df_11['Gender'], df_11['Engaged sessions'], color = 'plum')
plt.xlabel('Gender')
plt.ylabel('Engaged Sessions')
plt.title('Engaged Sessions by Genders')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_11['Gender'],df_11['Engagement rate'],marker = 'o', linestyle = '--',color = 'plum')
plt.xlabel('Gender')
plt.ylabel('Engagement rate')
plt.title('Engagement rate based on Gender')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_11['Gender'],df_11['Engaged sessions per user'], marker = 'o', linestyle = '-', color = 'plum')
plt.xlabel('Gender')
plt.ylabel('Engaged sessions per user')
plt.title('Engaged sessions per user by Gender')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_11['Gender'],df_11['Average engagement time'],marker = 's', linestyle = '-.', color = 'plum')
plt.fill_between(df_11['Gender'],df_11['Average engagement time'], color='plum', alpha=0.2)
plt.xlabel('Gender')
plt.ylabel('Average Engagement Time per user')
plt.title('Average Engagement Time based on Gender')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.bar(df_11['Gender'], df_11['Event count'], color='plum')
plt.xlabel('Gender')
plt.ylabel('Event Count')
plt.title('Event Count based on Gender')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.bar(df_11['Gender'], df_11['Conversions'], color='plum')
plt.plot(df_11['Gender'], df_11['Conversions'], marker = 'o', linestyle = '--', color = 'purple')
plt.xlabel('Gender')
plt.ylabel('Conversions')
plt.title('Conversions by Gender')
plt.show()

# %% [markdown]
# # **9. USER BY INTEREST**

# %%
df_12.head()
# Out:
#                                        Interests  Users  New users  \
# 0                                       Shoppers  10950       9256
# 1  Media & Entertainment/Comics & Animation Fans  10946       9247
# 2                  Technology/Mobile Enthusiasts  10934       9239
# 3              Food & Dining/Cooking Enthusiasts   8410       6970
# 4        Sports & Fitness/Health & Fitness Buffs   5844       4580
#
#    Engaged sessions  Engagement rate  Engaged sessions per user  \
# 0             15652         0.581534                   1.429406
# 1             15680         0.583008                   1.432487
# 2             15619         0.582451                   1.428480
# 3             12332         0.602325                   1.466350
# 4              8226         0.588328                   1.407598
#
#    Average engagement time  Event count  Conversions  Total revenue
# 0                 162.8347       490664        86846              0
# ...

# %%
df_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Interests                  89 non-null     object
#  1   Users                      89 non-null     int64
#  2   New users                  89 non-null     int64
#  3   Engaged sessions           89 non-null     int64
#  4   Engagement rate            89 non-null     float64
#  5   Engaged sessions per user  89 non-null     float64
#  6   Average engagement time    89 non-null     float64
#  7   Event count                89 non-null     int64
#  8   Conversions                89 non-null     int64
#  9   Total revenue              89 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 7.1+ KB

# %%
df_12.shape
# Out:
# (89, 10)

# %%
df_9.isnull().sum()
# Out:
# Country                      0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df_12['Interests'].value_counts()
# Out:
# Shoppers                                                          1
# Lifestyles & Hobbies/Green Living Enthusiasts                     1
# Media & Entertainment/TV Lovers/Game, Reality & Talk Show Fans    1
# News & Politics/Avid News Readers/Avid Local News Readers         1
# Media & Entertainment/Movie Lovers/Fans of South Asian Film       1
#                                                                  ..
# Media & Entertainment/Book Lovers                                 1
# Technology/Technophiles                                           1
# Vehicles & Transportation/Auto Enthusiasts                        1
# Media & Entertainment/Gamers/Action Game Fans                     1
# Sports & Fitness/Sports Fans/Fans of American Football            1
# Name: Interests, Length: 89, dtype: int64

# %%
df_12.describe()
# Out:
#               Users    New users  Engaged sessions  Engagement rate  \
# count     89.000000    89.000000         89.000000        89.000000
# mean    2411.044944  1911.280899       3373.932584         0.619191
# std     2480.482385  2059.110984       3544.597874         0.081918
# min       10.000000     3.000000          9.000000         0.450000
# 25%      107.000000    72.000000        142.000000         0.576499
# 50%     1942.000000  1566.000000       2608.000000         0.618416
# 75%     3652.000000  2872.000000       5443.000000         0.666153
# max    10950.000000  9256.000000      15680.000000         0.840000
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                  89.000000                89.000000      89.000000
# mean                    1.339172               219.531871  110565.202247
# std                     0.258550               366.821595  114195.875599
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR USER INTEREST**

# %%
df12_users = df_12.sort_values(by='Users', ascending=False)
top12_users = df12_users.head(5)

plt.figure(figsize = (20,8))
plt.bar(top12_users['Interests'], top12_users['Users'], color='#FF6347')
plt.xlabel('Interests')
plt.ylabel('Top Users')
plt.title('Top Users by User Interests')
plt.show()

# %%
df12_users = df_12.sort_values(by='Users', ascending=False)
bottom12_users = df12_users.tail(5)

plt.figure(figsize = (20,8))
plt.bar(bottom12_users['Interests'], bottom12_users['Users'], color='#FF6347')
plt.xlabel('Interests')
plt.ylabel('Top Users')
plt.title('Bottom Users by User Interests')
plt.show()

# %%
df12_nusers = df_12.sort_values(by='New users', ascending=False)
top12_nusers = df12_nusers.head(5)

plt.figure(figsize = (20,8))
plt.barh(top12_nusers['Interests'], top12_nusers['New users'], color='#FF6347')
plt.xlabel('Interests')
plt.ylabel('New Users')
plt.title('New Users by Top User Interests')
plt.show()

# %%
df12_nusers = df_12.sort_values(by='New users', ascending=False)
bottom12_nusers = df12_nusers.tail(10)

plt.figure(figsize = (20,8))
plt.barh(bottom12_nusers['Interests'], bottom12_nusers['New users'], color='#FF6347')
plt.xlabel('Interests')
plt.ylabel('New Users')
plt.title('New Users by Bottom User Interests')
plt.show()

# %%
df12_es = df_12.sort_values(by='Engaged sessions', ascending=False)
top12_es = df12_es.head(5)

plt.figure(figsize = (20,8))
plt.bar(top12_es['Interests'], top12_es['Engaged sessions'], color='#FF6347')
plt.xlabel('Interests')
plt.ylabel('Engaged Sessions')
plt.title('Engaged Sessions by User Interests')
plt.show()

# %%
df12_er = df_12.sort_values(by='Engagement rate', ascending=False)
top12_er = df12_er.head(5)

plt.figure(figsize = (20,8))
plt.plot(top12_er['Interests'],top12_er['Engagement rate'],marker = 'o', linestyle = '--',color = '#FF6347')
plt.xlabel('Interests')
plt.ylabel('Engagement rate')
plt.title('Engagement rate based on User Interests')
plt.show()

# %%
df12_espu = df_12.sort_values(by='Engaged sessions per user', ascending=False)
top12_espu = df12_espu.head(5)

plt.figure(figsize = (25,8))
plt.plot(top12_espu['Interests'],top12_espu['Engagement rate'], marker = 'o', linestyle = '-', color = '#FF6347')
plt.xlabel('Interests')
plt.ylabel('Engagement rate')
plt.title('Engaged rate by User Interests')
plt.show()

# %%
df12_aet = df_12.sort_values(by='Average engagement time', ascending=False)
top12_aet = df12_aet.head(5)

plt.figure(figsize = (20,8))
plt.plot(top12_aet['Interests'],top12_aet['Average engagement time'],marker = 's', linestyle = '-.', color = '#FF6347')
plt.fill_between(top12_aet['Interests'],top12_aet['Average engagement time'], color='#FF6347', alpha=0.2)
plt.xlabel('Interests')
plt.ylabel('Average Engagement Time per user')
plt.title('Average Engagement Time based on User Interests')
plt.show()

# %%
df12_ec = df_12.sort_values(by='Event count', ascending=False)
top12_ec = df12_ec.head(5)

plt.figure(figsize = (20,8))
plt.bar(top12_ec['Interests'], top12_ec['Event count'], color='#FF6347')
plt.xlabel('Interests')
plt.ylabel('Event Count')
plt.title('Event Count based on User Interests')
plt.show()

# %%
df12_con = df_12.sort_values(by='Conversions', ascending=False)
top12_con = df12_con.head(5)

plt.figure(figsize=(20, 8))
plt.bar(top12_con['Interests'], top12_con['Conversions'], color='#FF6347')
plt.plot(top12_con['Interests'], top12_con['Conversions'], marker = 'o', linestyle = '--', color = 'red')
plt.xlabel('Interests')
plt.ylabel('Conversions')
plt.title('Conversions based on User Interests')
plt.show()

# %%
df12_con = df_12.sort_values(by='Conversions', ascending=False)
bottom12_con = df12_con.tail(5)

plt.figure(figsize=(25, 8))
plt.bar(bottom12_con['Interests'], bottom12_con['Conversions'], color='#FF6347')
plt.plot(bottom12_con['Interests'], bottom12_con['Conversions'], marker = 'o', linestyle = '--', color = 'red')
plt.xlabel('Interests')
plt.ylabel('Conversions')
plt.title('Conversions based on Least User Interests')
plt.show()

# %% [markdown]
# # **10. USER BY LANGUAGE**

# %%
df_13.head()
# Out:
#    Language  Users  New users  Engaged sessions  Engagement rate  \
# 0   English  22495      21990             40639         0.595147
# 1     Hindi    586        552               798         0.406314
# 2   Marathi     85         84                98         0.426087
# 3  Gujarati     78         77               100         0.448430
# 4    Telugu     43         42                56         0.455285
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.806579                341.36350      1297970
# 1                   1.361775                 60.03413        13523
# 2                   1.152941                 38.48235         1589
# 3                   1.282051                 46.53846         1794
# 4                   1.302326                 36.65116          812
#
#    Conversions  Total revenue
# 0       189946              0
# 1         2699              0
# 2          323              0
# 3          327              0
# ...

# %%
df_13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Language                   24 non-null     object
#  1   Users                      24 non-null     int64
#  2   New users                  24 non-null     int64
#  3   Engaged sessions           24 non-null     int64
#  4   Engagement rate            24 non-null     float64
#  5   Engaged sessions per user  24 non-null     float64
#  6   Average engagement time    24 non-null     float64
#  7   Event count                24 non-null     int64
#  8   Conversions                24 non-null     int64
#  9   Total revenue              24 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 2.0+ KB

# %%
df_13.shape
# Out:
# (24, 10)

# %%
df_13.isnull().sum()
# Out:
# Language                     0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df_13.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count     24.000000     24.000000         24.000000        24.000000
# mean     975.916667    953.000000       1744.833333         0.535395
# std     4585.079838   4482.258359       8285.991965         0.321298
# min        0.000000      0.000000          0.000000         0.000000
# 25%        1.000000      1.000000          1.000000         0.421144
# 50%        7.000000      7.000000          7.000000         0.509036
# 75%       21.750000     20.250000         37.750000         0.677083
# max    22495.000000  21990.000000      40639.000000         1.000000
#
#        Engaged sessions per user  Average engagement time   Event count  \
# count                  24.000000                24.000000  2.400000e+01
# mean                    1.046263                65.527106  5.493871e+04
# std                     0.642224                83.316618  2.647787e+05
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR USER LANGUAGE**

# %%
df_13.head()
# Out:
#    Language  Users  New users  Engaged sessions  Engagement rate  \
# 0   English  22495      21990             40639         0.595147
# 1     Hindi    586        552               798         0.406314
# 2   Marathi     85         84                98         0.426087
# 3  Gujarati     78         77               100         0.448430
# 4    Telugu     43         42                56         0.455285
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.806579                341.36350      1297970
# 1                   1.361775                 60.03413        13523
# 2                   1.152941                 38.48235         1589
# 3                   1.282051                 46.53846         1794
# 4                   1.302326                 36.65116          812
#
#    Conversions  Total revenue
# 0       189946              0
# 1         2699              0
# 2          323              0
# 3          327              0
# ...

# %%
df13_lang = df_13.sort_values(by='Users', ascending=False)
top_lang = df13_lang.head(5)

plt.figure(figsize = (20,8))
plt.bar(top_lang['Language'], top_lang['Users'], color='#0a534a')
plt.xlabel('Language')
plt.ylabel('Top Users')
plt.title('Top Users by Languages')
plt.show()

# %%
df13_nusers = df_13.sort_values(by = 'New users',ascending = False)
top13_nusers = df13_nusers.head(10)

plt.figure(figsize = (20,8))
plt.bar(top13_nusers['Language'], top13_nusers['New users'], color='#0a534a')
plt.xlabel('Language')
plt.ylabel('New Users')
plt.title('New Users by Languages')
plt.show()

# %%
top13_esessions = df_13.sort_values(by = 'Engaged sessions', ascending = False)
df13_es = top13_esessions.head(10)

plt.figure(figsize = (20,8))
plt.barh(df13_es['Language'], df13_es['Engaged sessions'], color = '#0a534a')
plt.xlabel('Languages')
plt.ylabel('Engaged Sessions')
plt.title('Engaged Sessions by User Languages')
plt.show()

# %%
df13_erate = df_13.sort_values(by = 'Engagement rate', ascending = False)
top13_erate = df13_erate.head(10)

plt.figure(figsize = (20,8))
plt.plot(top13_erate['Language'],top13_erate['Engagement rate'],marker = 'o', linestyle = '--', color = '#0a534a')
plt.xlabel('Language')
plt.ylabel('Engagement rate')
plt.title('Engagement rate based on Language')
plt.show()

# %%
df13_espu = df_13.sort_values(by = 'Engaged sessions per user', ascending = False)
top13_espu = df13_espu.head(10)

plt.figure(figsize = (20,8))
plt.plot(top13_espu['Language'],top13_espu['Engaged sessions per user'], marker = 'o', linestyle = '-', color = '#0a534a')
plt.xlabel('Language')
plt.ylabel('Engaged sessions per user')
plt.title('Engaged sessions per user by User Language')
plt.show()

# %%
df13_aet = df_13.sort_values(by = 'Average engagement time', ascending = False)
top13_aet = df13_aet.head(5)

plt.figure(figsize = (20,8))
plt.plot(top13_aet['Language'],top13_aet['Average engagement time'],marker = 's', linestyle = '-.', color = '#0a534a')
plt.fill_between(top13_aet['Language'],top13_aet['Average engagement time'], color='green', alpha=0.2)
plt.xlabel('Language')
plt.ylabel('Average Engagement Time per user')
plt.title('Average Engagement Time based on User Language')
plt.show()

# %%
df13_ec = df_13.sort_values(by = 'Event count', ascending = False)
top13_es = df13_es.head(10)

plt.figure(figsize = (20,8))
plt.bar(top13_es['Language'], top13_es['Event count'], color='#0a534a')
plt.xlabel('Language')
plt.ylabel('Event Count')
plt.title('Event Count based on User Language')
plt.show()

# %%
df13_con = df_13.sort_values(by = 'Conversions', ascending = False)
top13_con = df13_con.head(5)

plt.figure(figsize=(20, 8))
plt.bar(top13_con['Language'], top13_con['Conversions'], color='#0a534a')
plt.plot(top13_con['Language'], top13_con['Conversions'], marker = 'o', linestyle = '--', color = 'green')
plt.xlabel('Language')
plt.ylabel('Conversions')
plt.title('Conversions by User Language')
plt.show()

# %% [markdown]
# # **11. USER BY AGE**

# %%
df_14.head()
# Out:
#        Age  Users  New users  Engaged sessions  Engagement rate  \
# 0  unknown  14303      13636             24976         0.569098
# 1    18-24   4282       3678              7291         0.695308
# 2    25-34   2920       2161              3749         0.504780
# 3      65+   1422       1081              1640         0.539829
# 4    55-64   1403        979              1552         0.519411
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.746207                422.22330       817501
# 1                   1.702709                251.16300       309328
# 2                   1.283904                 97.24144        90074
# 3                   1.153305                 52.30661        24780
# 4                   1.106201                 55.37063        25169
#
#    Conversions  Total revenue
# 0        99310              0
# 1        53661              0
# 2        20172              0
# 3         4891              0
# ...

# %%
df_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        7 non-null      object
#  1   Users                      7 non-null      int64
#  2   New users                  7 non-null      int64
#  3   Engaged sessions           7 non-null      int64
#  4   Engagement rate            7 non-null      float64
#  5   Engaged sessions per user  7 non-null      float64
#  6   Average engagement time    7 non-null      float64
#  7   Event count                7 non-null      int64
#  8   Conversions                7 non-null      int64
#  9   Total revenue              7 non-null      int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 688.0+ bytes

# %%
df_14.shape
# Out:
# (7, 10)

# %%
df_14.isnull().sum()
# Out:
# Age                          0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
df_14.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count      7.000000      7.000000          7.000000         7.000000
# mean    3763.142857   3267.428571       5929.857143         0.557245
# std     4802.784277   4698.464389       8686.797289         0.065705
# min      810.000000    552.000000        881.000000         0.504780
# 25%     1302.500000    882.000000       1486.000000         0.514917
# 50%     1422.000000   1081.000000       1640.000000         0.539829
# 75%     3601.000000   2919.500000       5520.000000         0.565480
# max    14303.000000  13636.000000      24976.000000         0.695308
#
#        Engaged sessions per user  Average engagement time    Event count  \
# count                   7.000000                 7.000000       7.000000
# mean                    1.323049               151.275793  188361.285714
# std                     0.281679               137.114289  296206.859168
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR USER AGE**

# %%
df_14.head()
# Out:
#        Age  Users  New users  Engaged sessions  Engagement rate  \
# 0  unknown  14303      13636             24976         0.569098
# 1    18-24   4282       3678              7291         0.695308
# 2    25-34   2920       2161              3749         0.504780
# 3      65+   1422       1081              1640         0.539829
# 4    55-64   1403        979              1552         0.519411
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.746207                422.22330       817501
# 1                   1.702709                251.16300       309328
# 2                   1.283904                 97.24144        90074
# 3                   1.153305                 52.30661        24780
# 4                   1.106201                 55.37063        25169
#
#    Conversions  Total revenue
# 0        99310              0
# 1        53661              0
# 2        20172              0
# 3         4891              0
# ...

# %%
age = df_14["Age"].value_counts()
users = df_14['Users']
plt.figure(figsize = (25,10))
plt.pie(users.values, labels=age.index, autopct="%1.1f%%")
plt.title("Pie Chart of Users by Age")
plt.legend(loc = 'upper right')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.bar(df_14['Age'], df_14['New users'], color='#650021')
plt.xlabel('Age')
plt.ylabel('New Users')
plt.title('New Users by Age')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.barh(df_14['Age'], df_14['Engaged sessions'], color = 'maroon')
plt.xlabel('Age')
plt.ylabel('Engaged Sessions')
plt.title('Engaged Sessions by User Age')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_14['Age'],df_14['Engagement rate'],marker = 'o', linestyle = '--', color = 'maroon')
plt.xlabel('Age')
plt.ylabel('Engagement rate')
plt.title('Engagement rate based on User Age')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_14['Age'],df_14['Engaged sessions per user'], marker = 'o', linestyle = '-', color = 'maroon')
plt.xlabel('Age')
plt.ylabel('Engaged sessions per user')
plt.title('Engaged sessions per user by User Age')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.plot(df_14['Age'],df_14['Average engagement time'],marker = 's', linestyle = '-.', color = 'maroon')
plt.fill_between(df_14['Age'],df_14['Average engagement time'], color='maroon', alpha=0.2)
plt.xlabel('Age')
plt.ylabel('Average Engagement Time per user')
plt.title('Average Engagement Time based on User Age')
plt.show()

# %%
plt.figure(figsize = (20,8))
plt.bar(df_14['Age'], df_14['Event count'], color='maroon')
plt.xlabel('Age')
plt.ylabel('Event Count')
plt.title('Event Count based on User Age')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.bar(df_14['Age'], df_14['Conversions'], color='maroon')
plt.plot(df_14['Age'],df_14['Conversions'], marker = 'o', linestyle = '--', color = 'black')
plt.xlabel('Age')
plt.ylabel('Conversions')
plt.title('Conversions by User Age')
plt.show()

# %% [markdown]
# # **12. GOOGLE ADS REPORT**

# %%
df_15.head()
# Out:
#                Session Google Ads campaign  Users  Sessions  Engaged sessions  \
# 0        App Installation for May --Shahid   5429     10936              6276
# 1      App Install-States-A200Inst-20Jun22    842      1655               968
# 2  App Install-States-B100Installs-22Jun22    742      1332               780
# 3          App Install for April -- Shahid    473       976               546
# 4  Video-AppInstall-PS-Internships-11Jul22    510       966               515
#
#    Google Ads clicks  Google Ads cost  Google Ads cost per click  Conversions  \
# 0             147100       179175.000                   1.218049        12257
# 1              28742        24309.130                   0.845770         1794
# 2              17809        22374.580                   1.256363         1422
# 3              19302        20525.180                   1.063370         1115
# 4               9831         6377.833                   0.648747         1032
#
# ...

# %%
df_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Session Google Ads campaign  15 non-null     object
#  1   Users                        15 non-null     int64
#  2   Sessions                     15 non-null     int64
#  3   Engaged sessions             15 non-null     int64
#  4   Google Ads clicks            15 non-null     int64
#  5   Google Ads cost              15 non-null     float64
#  6   Google Ads cost per click    15 non-null     float64
#  7   Conversions                  15 non-null     int64
#  8   Cost per conversion          15 non-null     float64
#  9   Event count                  15 non-null     int64
#  10  Total revenue                15 non-null     int64
#  11  Return on ad spend           15 non-null     int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1.5+ KB

# %%
df_15.shape
# Out:
# (15, 12)

# %%
df_15.isnull().sum()
# Out:
# Session Google Ads campaign    0
# Users                          0
# Sessions                       0
# Engaged sessions               0
# Google Ads clicks              0
# Google Ads cost                0
# Google Ads cost per click      0
# Conversions                    0
# Cost per conversion            0
# Event count                    0
# Total revenue                  0
# Return on ad spend             0
# dtype: int64

# %%
df_15.describe()
# Out:
#              Users      Sessions  Engaged sessions  Google Ads clicks  \
# count    15.000000     15.000000         15.000000          15.000000
# mean    666.200000   1274.133333        756.666667       17021.200000
# std    1348.253696   2721.749093       1558.314184       36934.069186
# min       2.000000      5.000000          5.000000          14.000000
# 25%      62.000000    100.500000         65.500000        1778.500000
# 50%     370.000000    610.000000        425.000000        4475.000000
# 75%     621.000000    971.000000        654.500000       14202.000000
# max    5429.000000  10936.000000       6276.000000      147100.000000
#
#        Google Ads cost  Google Ads cost per click   Conversions  \
# count        15.000000                  15.000000     15.000000
# mean      20089.196451                   1.237784   1421.533333
# std       44773.537357                   0.635640   3047.587755
# min          16.623960                   0.485200      5.000000
# ...

# %% [markdown]
# # **DATA ANALYSIS FOR GOOGLE ADS**

# %%
df15_users = df_15.sort_values(by = 'Users', ascending = False)
top15_users = df15_users.head(5)

plt.figure(figsize = (20,8))
plt.bar(top15_users['Session Google Ads campaign'], top15_users['Users'], color='#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Users')
plt.title('Users by Top Google Ads Campaign')
plt.show()

# %%
df15_users = df_15.sort_values(by = 'Users', ascending = False)
bottom15_users = df15_users.tail(5)

plt.figure(figsize = (20,8))
plt.bar(bottom15_users['Session Google Ads campaign'], bottom15_users['Users'], color='#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Users')
plt.title('Users by Bottom Google Ads Campaign')
plt.show()

# %%
df15_sessions = df_15.sort_values(by = 'Sessions', ascending = False)
top15_sessions = df15_sessions.head(5)

plt.figure(figsize = (20,8))
plt.bar(top15_sessions['Session Google Ads campaign'], top15_sessions['Sessions'],color = '#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Sessions')
plt.title('Sessions by Google Ads Campaign')
plt.show()

# %%
df15_sessions = df_15.sort_values(by = 'Sessions', ascending = False)
bottom15_sessions = df15_sessions.tail(5)

plt.figure(figsize = (20,8))
plt.bar(bottom15_sessions['Session Google Ads campaign'], bottom15_sessions['Sessions'],color = '#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Sessions')
plt.title('Bottom Sessions by Google Ads Campaign')
plt.show()

# %%
df15_es = df_15.sort_values(by = 'Engaged sessions', ascending = False)
top15_es = df15_sessions.head(5)

plt.figure(figsize = (20,8))
plt.barh(top15_es['Session Google Ads campaign'], top15_es['Engaged sessions'],color = '#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Engaged Sessions')
plt.title('Engaged Sessions by Top Google Ads Campaign')
plt.show()

# %%
df15_gac = df_15.sort_values(by = 'Google Ads clicks', ascending = False)
top15_gac = df15_gac.head(5)


plt.figure(figsize = (20,8))
plt.barh(top15_gac['Session Google Ads campaign'], top15_gac['Google Ads clicks'],color = '#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Google Ads Clicks')
plt.title('Google Ads Clicks based on Top Google Ads Campaign')
plt.show()

# %%
df15_gadc = df_15.sort_values(by = 'Google Ads cost', ascending = False)
top15_gadc = df15_gadc.head(5)

plt.figure(figsize = (20,8))
plt.plot(top15_gadc['Session Google Ads campaign'],top15_gadc['Google Ads cost'],marker = 'o', linestyle = '--', color = '#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Google Ads Cost')
plt.title('Google Ads Cost based on Google Ads Campaign')
plt.show()

# %%
df15_gapc = df_15.sort_values(by = 'Google Ads cost per click', ascending = False)
top15_gapc = df15_gapc.head(5)

plt.figure(figsize = (20,8))
plt.plot(top15_gapc['Session Google Ads campaign'],top15_gapc['Google Ads cost per click'],marker = 's', linestyle = '-', color = '#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Google Ads Cost per click')
plt.title('Google Ads Cost per click based on Google Ads Campaign')
plt.show()

# %%
df15_conv = df_15.sort_values(by = 'Conversions', ascending = False)
top15_conv = df15_conv.head(5)

plt.figure(figsize=(20, 8))
plt.bar(top15_conv['Session Google Ads campaign'], top15_conv['Conversions'], color='#13EAC9')
plt.plot(top15_conv['Session Google Ads campaign'],top15_conv['Conversions'], marker = 'o', linestyle = '--', color = '#0343DF')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Conversions')
plt.title('Conversions by Google Ads Campaign')
plt.show()

# %%
df15_conv = df_15.sort_values(by = 'Conversions', ascending = False)
bottom15_conv = df15_conv.tail(5)

plt.figure(figsize=(20, 8))
plt.bar(bottom15_conv['Session Google Ads campaign'], bottom15_conv['Conversions'], color='#13EAC9')
plt.plot(bottom15_conv['Session Google Ads campaign'],bottom15_conv['Conversions'], marker = 'o', linestyle = '--', color = '#0343DF')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Conversions')
plt.title('Conversions by Least performing Google Ads Campaign')
plt.show()

# %%
df15_cpc = df_15.sort_values(by = 'Cost per conversion', ascending = False)
top15_cpc = df15_cpc.head(5)

plt.figure(figsize = (20,8))
plt.plot(top15_cpc['Session Google Ads campaign'],top15_cpc['Cost per conversion'],marker = 's', linestyle = '-.', color = '#0343DF')
plt.fill_between(top15_cpc['Session Google Ads campaign'],top15_cpc['Cost per conversion'], color='#13EAC9', alpha=0.2)
plt.xlabel('Google Ads Campaign')
plt.ylabel('Cost per conversion')
plt.title('Cost per conversion based on Google Ads Campaign')
plt.show()

# %%
df15_ec = df_15.sort_values(by = 'Event count', ascending = False)
top15_ec = df15_ec.head(5)

plt.figure(figsize = (20,8))
plt.bar(top15_ec['Session Google Ads campaign'], top15_ec['Event count'],color = '#13EAC9')
plt.xlabel('Google Ads Campaign')
plt.ylabel('Event count')
plt.title('Event count by Google Ads Campaign')
plt.show()

# %% [markdown]
# # **THANK YOU**
#
# ## BY-PRAJWAL SALUTAGI
